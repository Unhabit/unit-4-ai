# %%
import gpt_2_simple as gpt2

# %%
gpt2.download_gpt2(
   model_name= '124M'
)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 2.16Git/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.26Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 13.4Git/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [01:34, 5.26Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 4.00Git/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 4.26Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 6.25Mit/s]

# %%
session = gpt2.start_tf_sess()

# %%
gpt2.finetune(
    session, 
	"minecraft.txt", 
	model_name="124M", 
	steps=100, 
	run_name="custom_ai"
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732631294.206587 9518061 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00, 2267.19it/s]
# dataset has 1345 tokens
# Training...
# [1 | 21.20] loss=2.23 avg=2.23
# [2 | 41.52] loss=2.48 avg=2.36
# [3 | 61.58] loss=2.37 avg=2.36
# [4 | 83.18] loss=1.75 avg=2.21
# [5 | 100.49] loss=1.61 avg=2.08
# [6 | 116.22] loss=1.45 avg=1.98
# [7 | 133.32] loss=1.27 avg=1.87
# [8 | 149.31] loss=1.21 avg=1.79
# [9 | 165.75] loss=1.02 avg=1.70
# [10 | 181.61] loss=0.89 avg=1.61
# [11 | 199.53] loss=0.80 avg=1.53
# [12 | 215.60] loss=0.68 avg=1.46
# [13 | 231.57] loss=0.59 avg=1.39
# [14 | 247.84] loss=0.52 avg=1.32
# [15 | 264.00] loss=0.51 avg=1.26
# [16 | 280.64] loss=0.37 avg=1.20
# ...

# %%
gpt2.generate(session, prefix="Q: What version first included horses?")
# Out:
# Q: What version first included horses?
# A: Version 1.6
#
# Q: What is the first material players usually collect?
# A: Wood
#
# Q: What type of ore is used to create the strongest armor?
# A: Netherite
#
# Q: What is the strongest type of pickaxe?
# A: Netherite Pickaxe
#
# Q: What Minecraft block is used to brew potions?
# A: Brewing Stand
#
# Q: What food restores the most health?
# A: Golden Apple
#
# Q: What block is used to enchant items?
# A: Enchanting Table
#
# Q: What valuable item can reset the spawn point?
# A: Bed
#
# Q: What container is needed to make every potion?
# A: Water bottle
#
# Q: What was supposed to be the name of the game?
# A: Cave Game
#
# Q: What is used to mine ores and stones in Minecraft?
# A: Pickaxe
#
# Q: In Minecraft, Creepers are terrified of?
# A: Ocelots
#
# Q: In Minecraft, sugar cane can produce what item?
# A: Paper
#
# Q: What item is required to tame a cat in Minecraft?
# A: Raw Cod or Raw Salmon
#
# ...

# %%
gpt2.generate(session, prefix="Q: What is the maximum number of players in a Minecraft Realms server?")
# Out:
# Q: What is the maximum number of players in a Minecraft Realms server?
# A: Ten
#
# Q: What is the largest minecart in Minecraft?
# A: Minecraft's "Aeramic Slabs"
#
# Q: What block is unbreakable in survival mode?
# A: Bedrock
#
# Q: What are the large jellyfish-like creatures in the Nether?
# A: Ghasts
#
# Q: What creature drops feathers and infects villagers?
# A: Zombie
#
# Q: What creature can climb walls and is passive during the day?
# A: Spider
#
# Q: What is the first material players usually collect?
# A: Wood
#
# Q: What type of ore is used to create the strongest armor?
# A: Netherite
#
# Q: What is the strongest type of pickaxe?
# A: Netherite Pickaxe
#
# Q: What Minecraft block is used to brew potions?
# A: Brewing Stand
#
# Q: What food restores the most health?
# A: Golden Apple
#
# Q: What block is used to enchant items?
# A: Enchanting Table
#
# Q: What valuable item can reset the spawn point?
# A: Bed
#
# Q: What container is needed to make every potion?
# ...

# %%
gpt2.generate(session, prefix="Q: What year was Minecraft officially released?")
# Out:
# Q: What year was Minecraft officially released?
# A: 2011
#
# Q: What platform was Minecraft first developed on?
# A: PC
#
# Q: What is the first version of Minecraft?
# A: Minecraft
#
# Q: What release was Minecraft without external support?
# A: Minecraft: Unturned
#
# Q: What is the first version of Minecraft without Geomancy?
# A: Minecraft: Unturned
#
# Q: What update added the Netherite material?
# A: Netherite Pickaxe
#
# Q: What update added the ocean monuments?
# A: The Update Aquatic
#
# Q: What version of Minecraft is used to brew potions?
# A: Brewing Stand
#
# Q: What version is used to test and tame bees?
# A: Brewing Stand
#
# Q: What food restores the most health?
# A: Golden Apple
#
# Q: What block is used to enchant items?
# A: Enchanting Table
#
# Q: What valuable item can reset the spawn point?
# A: Bed
#
# Q: What container is needed to make every potion?
# A: Water bottle
#
# Q: What was supposed to be the name of the game?
# A: Cave Game
#
# ...
